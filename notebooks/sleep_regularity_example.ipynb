# %% [raw]
# # Sleep Regularity Chart Example
#
# This notebook demonstrates how to create sleep regularity charts similar to health app visualizations.

# %%
# Import required modules
import sys
import os

# Add src to path
sys.path.append(os.path.join(os.path.dirname(os.getcwd()), 'src'))

from visualization.sleep_chart import create_sleep_chart, SleepRegularityChart
from visualization.sleep_utils import generate_sample_data, calculate_sleep_metrics

# %% [raw]
# ## Generate Sample Data
#
# First, let's create some sample sleep data that matches the pattern from your image.

# %%
# Generate sample sleep data
sleep_data = generate_sample_data()

print("Sample Sleep Data:")
for data in sleep_data:
    print(f"  {data['day']}: {data['bedtime']} - {data['wake_time']}")
# Out:
# Sample Sleep Data:
#   T: 22:39 - 07:47
#   F: 21:31 - 09:04
#   S: 22:17 - 08:32
#   S: 22:18 - 08:24
#   M: 00:06 - 07:01
#   T: 21:49 - 08:04
#   W: 22:10 - 07:05

# %% [raw]
# ## Create Sleep Regularity Chart
#
# Now let's create the sleep regularity chart using the sample data.

# %%
# Create sleep regularity chart
chart = create_sleep_chart(
    sleep_data=sleep_data,
    title="SLEEP REGULARITY",
    figsize=(12, 8)
)

chart.show()
# Out:
# /Users/mgartner/Documents/personal_projects/healthdatabase/src/visualization/sleep_chart.py:188: UserWarning: Glyph 127769 (\N{CRESCENT MOON}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /Users/mgartner/Documents/personal_projects/healthdatabase/venv/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 127769 (\N{CRESCENT MOON}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
